# %% [markdown]
# <a href="https://colab.research.google.com/github/bavya1309/bavyatulasi_dulam/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 07:09:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   153MB/s    in 0.5s
#
# 2024-03-25 07:09:15 (153 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3589   1801.06432v1  Dictionary learning and component analysis mod...  stat
# 20272  1507.04091v1  In real clustering applications, proximity dat...    cs
# 34108   1401.2258v1  This work compares concept models for cross-la...    cs
# 22295  1512.02543v1  We investigate a class of feature allocation m...  stat
# 794    1511.09249v1  This paper addresses the general problem of re...    cs
# ...             ...                                                ...   ...
# 21662   1306.1043v2  Causal inference relies on the structure of a ...  stat
# 33173  1803.02453v1  We present a systematic approach for achieving...    cs
# 3547   1711.09219v1  Kernel methods are powerful tools to capture n...  stat
# 7679   1802.07756v1  Motivation: Thanks to digitization, we often h...  stat
# 34938   0808.0549v5  This paper has been withdrawn by the author du...    cs
#
#                                                    title  year  \
# 3589                 Robust Kronecker Component Analysis  2018
# 20272     Evidential relational clustering using medoids  2015
# 34108  Assessing Wikipedia-Based Cross-Language Retri...  2014
# 22295                 Gibbs-type Indian buffet processes  2015
# 794    On Learning to Think: Algorithmic Information ...  2015
# ...                                                  ...   ...
# 21662  Structural Intervention Distance (SID) for Eva...  2013
# 33173       A Reductions Approach to Fair Classification  2018
# 3547                              Stacked Kernel Network  2017
# 7679   Determining the best classifier for predicting...  2018
# 34938  Resource Allocation of MU-OFDM Based Cognitive...  2008
#
#                                                 keywords
# 3589   [dictionary, component, fundamental, represent...
# 20272  [clustering, applications, proximity, similari...
# 34108  [retrieval, probabilistic, multilingual, docum...
# 22295  [investigate, allocation, generalize, paramete...
# 794    [addresses, reinforcement, partially, observab...
# ...                                                  ...
# 21662  [inference, structure, different, different, i...
# 33173  [systematic, achieving, classification, quanti...
# 3547   [nonlinear, implicitly, dimensional, nonlinear...
# 7679   [motivation, digitization, databases, consisti...
# 34938    [withdrawn, allocation, cognitive, information]
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3589     [dictionary, component, fundamental, represent...
# 20272    [clustering, applications, proximity, similari...
# 34108    [retrieval, probabilistic, multilingual, docum...
# 22295    [investigate, allocation, generalize, paramete...
# 794      [addresses, reinforcement, partially, observab...
#                                ...
# 6626     [regularization, adversarial, smoothness, dist...
# 28326    [synthesizing, filamentary, structured, realis...
# 37890    [procedures, interactions, stochastic, integra...
# 13679    [architecture, differentiable, trainable, arch...
# 12579    [reinforcement, criterion, considered, interac...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8840 words.
# Out of those 4581 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0ffdf705-144a-4837-b89d-6c9137014715" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ffdf705-144a-4837-b89d-6c9137014715")) {                    Plotly.newPlot(                        "0ffdf705-144a-4837-b89d-6c9137014715",                        [{"x":["factorization","component","properties","corrupted","kronecker","representations","separability","background","reduction","corruption","optimality","extraction","completion","performing","decomposition","dictionary","significantly","including","complexity","robustness","comparison","approaches","structure","algorithm","dimensionality","denoising","unfortunately","dimensional","computations","fundamental","dictionaries","subtraction","effectiveness","applications","decomposable","appealing","expensive","magnitude","leverages","conversely","demonstrated","principle","nonnegativity","restricted","efficient","experiments","uncertainty","similarities","algorithms","framework","synthetic","proximity","functions","mechanism","imprecise","prototype","extension","partitioning","represent","misclassification","attributes","evidential","initializations","performance","illustrate","relational","explicitly","dissimilarities","theoretical","prototypes","clustering","described","probabilistic","efficiency","competitive","translation","documents","combination","smoothing","particular","therefore","different","monolingual","emphasize","integrate","weighting","retrieval","soundness","considering","allocation","improvements","favorably","multilingual","dirichlet","assessing","normalized","previously","available","wikipedia","information","questions","interesting","increased","characteristics","parameter","asymptotic","behaviors","contained","partitions","subclasses","highlight","posterior","analogous","processes","corresponding","generalize","procedure","translates","parameterized","containing","numerical","inference","investigate","partially","predictive","controllers","environment","addresses","recurrent","reinforcement","environments","submitted","simulated","essentially","sequences","observable","combinations","reasoning","algorithmic","experimental","initially","detection","responses","physiological","components","difficult","undesired","demonstrate","compressed","techniques","processing","superposition","underlying","measurement","generation","conducted","generating","frameworks","occupation","researchers","typically","mentioned","structured","important","answering","relationship","generated","conclusions","represents","independent","specificity","automated","utilizing","classification","objective","sensitivity","determine","classifying","endpoints","databases","diagnosis","screening","constructed","effective","distinguish","degeneration","datapoints","categorize","coherence","electronic","respectively","extracted","implications","validation","performed","opportunity","tomography","considerably","approximate","threshold"],"y":[30,103,226,20,2,258,7,78,104,4,24,139,33,76,62,61,294,259,246,106,133,434,335,803,55,35,35,182,30,92,26,6,183,448,3,17,58,51,38,6,97,58,1,57,438,591,81,35,645,577,158,9,215,97,7,30,63,19,114,12,63,13,5,954,74,41,74,2,161,7,157,77,162,162,110,109,71,118,17,296,134,795,20,12,42,19,114,8,77,34,107,26,20,30,20,30,95,317,23,711,67,65,28,89,124,28,27,15,17,3,40,42,12,110,144,54,127,4,15,64,93,225,159,50,63,8,111,60,138,121,72,10,64,34,103,23,34,118,44,382,26,333,32,7,104,164,5,571,29,380,294,4,119,30,146,71,100,28,2,76,110,16,113,362,59,87,176,17,47,120,10,101,43,496,167,27,76,36,2,56,55,6,58,246,36,1,2,5,20,18,92,112,28,49,130,7,17,28,119,28],"type":"bar"},{"x":["factorization","component","properties","corrupted","kronecker","representations","separability","ba ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4581,), (4581, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5067873303167421);'>Detection</span> <span style=''>of</span> <span style=''>Face</span> <span style=''>using</span> <span style=''>Viola</span> <span style=''>Jones</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6929637526652452);'>Recognition</span> <span style=''>using</span> <span style=''>Back</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style=''>Neural</span> <span style=''>Network</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5067873303167421);'>Detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6929637526652452);'>recognition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>facial</span> <span style=''>images</span> <span style=''>of</span> <span style=''>people</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>intricate</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>has</span> <span style=''>garnered</span> <span style=''>much</span> <span style='background-color:rgba(0, 255, 0, 0.38996138996138996);'>attention</span> <span style=''>during</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>ever</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>numerous</span> <span style=''>fields</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555555);'>continues</span> <span style=''>to</span> <span style=''>pose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>it</span> <span style=''>Its</span> <span style=''>scope</span> <span style=''>extends</span> <span style=''>to</span> <span style=''>catering</span> <span style=''>the</span> <span style=''>security</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157894);'>commercial</span> <span style=''>and</span> <span style=''>law</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>enforcement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>Research</span> <span style=''>for</span> <span style=''>moreover</span> <span style=''>a</span> <span style=''>decade</span> <span style=''>on</span> <span style=''>this</span> <span style=''>subject</span> <span style=''>has</span> <span style=''>brought</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>remarkable</span> <span style='background-color:rgba(0, 255, 0, 0.5180722891566265);'>development</span> <span style=''>with</span> <span style=''>the</span> <span style=''>modus</span> <span style=''>operandi</span> <span style=''>like</span> <span style=''>human</span> <span style=''>computer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interaction</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>biometric</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>content</span> <span style=''>based</span> <span style=''>coding</span> <span style=''>of</span> <span style=''>images</span> <span style=''>videos</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6818181818181819);'>surveillance</span> <span style=''>A</span> <span style=''>trivial</span> <span style=''>task</span> <span style=''>for</span> <span style=''>brain</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546) ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Problems</span> <span style=''>with</span> <span style=''>Non</span> <span style=''>smooth</span> <span style=''>Penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>andor</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>(or</span> <span style=''>penalization)</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>control</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>induce</span> <span style=''>desired</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>Each</span> <span style=''>penalty</span> <span style=''>has</span> <span style=''>a</span> <span style=''>weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicates</span> <span style=''>how</span> <span style=''>strongly</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>that</span> <span style=''>penalty</span> <span style=''>should</span> <span style=''>be</span> <span style=''>enforced</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Typically</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>chosen</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>error</span> <span style=''>on</span> <span style=''>a</span> <span style=''>separate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>set</span> <span style=''>using</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>grid</span> <span style=''>search</span> <span style=''>or</span> <span style=''>a</span> <span style=''>gradient</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style=''>It</span> <span style=''>is</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>to</span> <span style=''>tune</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>if</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>but</span> <span style=''>this</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>for</span> <span style=''>many</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>MMSE</span> <span style=''>and</span> <span style=''>MAP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Denoising</span> <span style=''>Under</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.39015151515151514);'>Representation</span> <span style=''>Modeling</span> <span style=''>Over</span> <span style=''>a</span> <span style=''>Unitary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <br/><br/><span style=''>Among</span> <span style=''>the</span> <span style=''>many</span> <span style=''>ways</span> <span style=''>to</span> <span style=''>model</span> <span style=''>signals</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>draws</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerable</span> <span style='background-color:rgba(0, 255, 0, 0.38996138996138996);'>attention</span> <span style=''>is</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.39015151515151514);'>representation</span> <span style=''>modeling</span> <span style=''>In</span> <span style=''>this</span> <span style=''>model</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>as</span> <span style=''>a</span> <span style=''>random</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>a</span> <span style=''>few</span> <span style=''>atoms</span> <span style=''>from</span> <span style=''>a</span> <span style=''>pre</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>two</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>the</span> <span style=''>Maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Aposteriori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>(MAP)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Minimum</span> <span style=''>Mean</span> <span style=''>Squared</span> <span style=''>Error</span> <span style=''>(MMSE)</span> <span style='background-color:rgba(255, 0, 0, 0.5652173913043479);'>estimators</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>is</span> <span style=''>unitary</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>both</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.5652173913043479);'>estimators</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>a</span> <span style=''>scalar</span> <span style='background-color:rgba(255, 0, 0, 0.7857142857142858);'>shrinkage</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>albeit</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3578138343296327);'>different</span> <span style=''>response</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Visualizing</span> <span style=''>Topics</span> <span style=''>with</span> <span style=''>Multi</span> <span style=''>Word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Expressions</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualizing</span> <span style=''>topics</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>terms</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style=''>large</span> <span style=''>text</span> <span style=''>corpora</span> <span style=''>using</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>finds</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>n</span> <span style=''>grams</span> <span style=''>related</span> <span style=''>to</span> <span style=''>a</span> <span style=''>topic</span> <span style=''>which</span> <span style=''>are</span> <span style=''>then</span> <span style=''>used</span> <span style=''>to</span> <span style=''>help</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>Compared</span> <span style=''>with</span> <span style=''>the</span> <span style=''>usual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>which</span> <span style=''>simply</span> <span style=''>lists</span> <span style=''>the</span> <span style=''>most</span> <span style=''>probable</span> <span style=''>topical</span> <span style=''>terms</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressions</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impression</span> <span style=''>for</span> <span style=''>what</span> <span style=''>a</span> <span style=''>topic</span> <span style=''>is</span> <span style=''>about</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>language</span> <span style=''>model</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>length</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressions</span> <span style=''>for</span> <span style=''>which</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>based</span> <span style=''>on</span> <span style=''>nested</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>tests</span> <span style=''>to</span> <span style=''>find</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>phrases</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>method</span> <span style='back ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09397417503586801)
# 	architecture (0.07639885222381636)
# 	processing (0.1054519368723099)
# 	representation (0.13163558106169296)
# 	experimental (0.13701578192252512)
# 	detection (0.11944045911047346)
# 	information (0.2550215208034433)
# 	convolutional (0.13701578192252512)
# 	different (0.2851506456241033)
# 	recognition (0.14239598278335724)
#
# Some Statistics words are:
# 	variables (0.12773359840954274)
# 	theoretical (0.14363817097415507)
# 	distributions (0.12475149105367793)
# 	statistical (0.15109343936381708)
# 	algorithm (0.38966202783300197)
# 	estimation (0.17345924453280318)
# 	inference (0.1918489065606362)
# 	distribution (0.18737574552683897)
# 	dimensional (0.1893638170974155)
# 	regression (0.18190854870775347)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a1e67d37-ead2-4402-b14d-c6cfcc38a17e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1e67d37-ead2-4402-b14d-c6cfcc38a17e")) {                    Plotly.newPlot(                        "a1e67d37-ead2-4402-b14d-c6cfcc38a17e",                        [{"x":["factorization","component","properties","corrupted","kronecker","representations","separability","background","reduction","corruption","optimality","extraction","completion","performing","decomposition","dictionary","significantly","including","complexity","robustness","comparison","approaches","structure","algorithm","dimensionality","denoising","unfortunately","dimensional","computations","fundamental","dictionaries","subtraction","effectiveness","applications","decomposable","appealing","expensive","magnitude","leverages","conversely","demonstrated","principle","nonnegativity","restricted","efficient","experiments","uncertainty","similarities","algorithms","framework","synthetic","proximity","functions","mechanism","imprecise","prototype","extension","partitioning","represent","misclassification","attributes","evidential","initializations","performance","illustrate","relational","explicitly","dissimilarities","theoretical","prototypes","clustering","described","probabilistic","efficiency","competitive","translation","documents","combination","smoothing","particular","therefore","different","monolingual","emphasize","integrate","weighting","retrieval","soundness","considering","allocation","improvements","favorably","multilingual","dirichlet","assessing","normalized","previously","available","wikipedia","information","questions","interesting","increased","characteristics","parameter","asymptotic","behaviors","contained","partitions","subclasses","highlight","posterior","analogous","processes","corresponding","generalize","procedure","translates","parameterized","containing","numerical","inference","investigate","partially","predictive","controllers","environment","addresses","recurrent","reinforcement","environments","submitted","simulated","essentially","sequences","observable","combinations","reasoning","algorithmic","experimental","initially","detection","responses","physiological","components","difficult","undesired","demonstrate","compressed","techniques","processing","superposition","underlying","measurement","generation","conducted","generating","frameworks","occupation","researchers","typically","mentioned","structured","important","answering","relationship","generated","conclusions","represents","independent","specificity","automated","utilizing","classification","objective","sensitivity","determine","classifying","endpoints","databases","diagnosis","screening","constructed","effective","distinguish","degeneration","datapoints","categorize","coherence","electronic","respectively","extracted","implications","validation","performed","opportunity","tomography","considerably","approximate","threshold","associated","transition","theoretic","noiseless","characterizing","transitions","collection","increases","variation","identifying","revealing","languages","discovering","experiment","unsupervised","correlate","dependency","typological","syntactic","realistic","induction","supervised","outperforms","engineered","prediction","relations","innovation","furthermore","dimension","noticeable","substitute","efficiently","vulnerability","indicated","accomplished","hierarchical","especially","stochastic","importance","optimization","technologies","identification","demonstrating","transferable","increasing","leveraging","gradients","prominent","adversarial","transferability","autonomous","coordinate","attacking","exploiting","literature","trajectory","empirical","comprehen ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	psychiatric
# 	inexactly
# 	supersparse
# 	sparsities
# 	tibshirani
# 	thermodynamic
# 	heartbeat
# 	retention
# 	thermostats
# 	tempering
# 	thermostat
# 	procrustes
# 	pessimistic
# 	thresholded
# 	selectors
# 	multiarmed
# 	corollary
# 	couplings
# 	manufacturability
# 	staleness
# Some words which never appear in Statistics papers:
# 	evidential
# 	occupation
# 	typological
# 	syntactic
# 	eligibility
# 	angiography
# 	centerlines
# 	misdiagnosis
# 	superpixel
# 	extensibility
# 	participate
# 	conversational
# 	interacted
# 	extractive
# 	summarisation
# 	constellations
# 	cambridge
# 	portrayed
# 	implanted
# 	initiated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0806198207079265e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
